# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-582038-1694700596/blob/main/21BCE0617_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Answer-1

# %%
import numpy as np
import pandas as pd

# %%
data = {'A': np.random.random(4), 'B': np.random.random(4), 'C': np.random.random(4), 'D': np.random.random(4)}
df = pd.DataFrame(data)
df
# Out:
#           A         B         C         D
# 0  0.342895  0.067597  0.517417  0.500070
# 1  0.233094  0.241291  0.915615  0.122886
# 2  0.896910  0.193814  0.510342  0.439368
# 3  0.208921  0.821709  0.039657  0.251797

# %% [markdown]
# # Answer-2

# %%
df.columns = ['Random value 1', 'Random value 2', 'Random value 3', 'Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.781436        0.526048        0.952432        0.368623
# 1        0.305854        0.863941        0.531066        0.314989
# 2        0.452728        0.409024        0.063386        0.522458
# 3        0.913675        0.459276        0.094499        0.400896

# %% [markdown]
# # Answer-3

# %%
df.describe
# Out:
# <bound method NDFrame.describe of    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.781436        0.526048        0.952432        0.368623
# 1        0.305854        0.863941        0.531066        0.314989
# 2        0.452728        0.409024        0.063386        0.522458
# 3        0.913675        0.459276        0.094499        0.400896>

# %% [markdown]
# # Answer-4

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.dtypes
# Out:
# Random value 1    float64
# Random value 2    float64
# Random value 3    float64
# Random value 4    float64
# dtype: object

# %% [markdown]
# # Answer-5

# %%
df.loc[:, ['Random value 1', 'Random value 2']]
# Out:
#    Random value 1  Random value 2
# 0        0.781436        0.526048
# 1        0.305854        0.863941
# 2        0.452728        0.409024
# 3        0.913675        0.459276

# %%
df.iloc[:,[0,1]]
# Out:
#    Random value 1  Random value 2
# 0        0.781436        0.526048
# 1        0.305854        0.863941
# 2        0.452728        0.409024
# 3        0.913675        0.459276
